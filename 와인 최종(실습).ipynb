# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import os
import tensorflow as tf

# %%
# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(seed)

df_pre = pd.read_csv('./dataset/wine.csv', header=None)
df = df_pre.sample(frac=0.15)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# %%
# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# %%
# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

model.fit(X, Y, validation_split=0.2, epochs=100, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.61426, saving model to ./model\01-0.6143.hdf5
#
# Epoch 00002: val_loss improved from 0.61426 to 0.44064, saving model to ./model\02-0.4406.hdf5
#
# Epoch 00003: val_loss improved from 0.44064 to 0.34035, saving model to ./model\03-0.3403.hdf5
#
# Epoch 00004: val_loss improved from 0.34035 to 0.33915, saving model to ./model\04-0.3392.hdf5
#
# Epoch 00005: val_loss did not improve from 0.33915
#
# Epoch 00006: val_loss improved from 0.33915 to 0.33060, saving model to ./model\06-0.3306.hdf5
#
# Epoch 00007: val_loss improved from 0.33060 to 0.31702, saving model to ./model\07-0.3170.hdf5
#
# Epoch 00008: val_loss improved from 0.31702 to 0.30839, saving model to ./model\08-0.3084.hdf5
#
# Epoch 00009: val_loss improved from 0.30839 to 0.30678, saving model to ./model\09-0.3068.hdf5
#
# Epoch 00010: val_loss did not improve from 0.30678
#
# Epoch 00011: val_loss did not improve from 0.30678
#
# Epoch 00012: val_loss improved from 0.30678 to 0.30642, saving model to ./model\12-0.3064.hdf5
#
# Epoch 00013: val_loss improved from 0.30642 to 0.30363, saving model to ./model\13-0.3036.hdf5
#
# Epoch 00014: val_loss improved from 0.30363 to 0.29922, saving model to ./model\14-0.2992.hdf5
#
# Epoch 00015: val_loss improved from 0.29922 to 0.29358, saving model to ./model\15-0.2936.hdf5
#
# Epoch 00016: val_loss improved from 0.29358 to 0.28822, saving model to ./model\16-0.2882.hdf5
#
# Epoch 00017: val_loss improved from 0.28822 to 0.28317, saving model to ./model\17-0.2832.hdf5
#
# Epoch 00018: val_loss improved from 0.28317 to 0.27882, saving model to ./model\18-0.2788.hdf5
#
# Epoch 00019: val_loss improved from 0.27882 to 0.27544, saving model to ./model\19-0.2754.hdf5
#
# Epoch 00020: val_loss improved from 0.27544 to 0.27371, saving model to ./model\20-0.2737.hdf5
#
# Epoch 00021: val_loss improved from 0.27371 to 0.27264, saving model to ./model\21-0.2726.hdf5
#
# Epoch 00022: val_loss improved from 0.27264 to 0.27117, saving model to ./model\22-0.2712.hdf5
#
# Epoch 00023: val_loss improved from 0.27117 to 0.26985, saving model to ./model\23-0.2699.hdf5
#
# Epoch 00024: val_loss improved from 0.26985 to 0.26892, saving model to ./model\24-0.2689.hdf5
#
# Epoch 00025: val_loss improved from 0.26892 to 0.26847, saving model to ./model\25-0.2685.hdf5
#
# Epoch 00026: val_loss did not improve from 0.26847
#
# Epoch 00027: val_loss did not improve from 0.26847
#
# Epoch 00028: val_loss did not improve from 0.26847
#
# Epoch 00029: val_loss did not improve from 0.26847
#
# Epoch 00030: val_loss improved from 0.26847 to 0.26688, saving model to ./model\30-0.2669.hdf5
#
# Epoch 00031: val_loss improved from 0.26688 to 0.26448, saving model to ./model\31-0.2645.hdf5
#
# Epoch 00032: val_loss improved from 0.26448 to 0.26228, saving model to ./model\32-0.2623.hdf5
#
# Epoch 00033: val_loss improved from 0.26228 to 0.26058, saving model to ./model\33-0.2606.hdf5
#
# Epoch 00034: val_loss improved from 0.26058 to 0.25921, saving model to ./model\34-0.2592.hdf5
#
# Epoch 00035: val_loss improved from 0.25921 to 0.25829, saving model to ./model\35-0.2583.hdf5
#
# Epoch 00036: val_loss improved from 0.25829 to 0.25744, saving model to ./model\36-0.2574.hdf5
#
# Epoch 00037: val_loss improved from 0.25744 to 0.25656, saving model to ./model\37-0.2566.hdf5
#
# Epoch 00038: val_loss improved from 0.25656 to 0.25560, saving model to ./model\38-0.2556.hdf5
#
# Epoch 00039: val_loss improved from 0.25560 to 0.25428, saving model to ./model\39-0.2543.hdf5
#
# Epoch 00040: val_loss improved from 0.25428 to 0.25327, saving model to ./model\40-0.2533.hdf5
#
# Epoch 00041: val_loss improved from 0.25327 to 0.25183, saving model to ./model\41-0.2518.hdf5
#
# Epoch 00042: val_loss improved from 0.25183 to 0.25059, saving model to ./model\42-0.2506.hdf5
#
# Epoch 00043: val_loss improved from 0.25059 to 0.24925, saving model to ./model\43-0.2493.hdf5
#
# Epoch 00044: val_loss improved from 0.24925 to 0.24772, saving model to ./model\44-0.2477.hdf5
#
# Epoch 00045: val_loss improved from 0.24772 to 0.24655, saving model to ./model\45-0.2466.hdf5
#
# Epoch 00046: val_loss improved from 0.24655 to 0.24592, saving model to ./model\46-0.2459.hdf5
#
# Epoch 00047: val_loss improved from 0.24592 to 0.24562, saving model to ./model\47-0.2456.hdf5
#
# Epoch 00048: val_loss improved from 0.24562 to 0.24453, saving model to ./model\48-0.2445.hdf5
#
# Epoch 00049: val_loss improved from 0.24453 to 0.24245, saving model to ./model\49-0.2424.hdf5
#
# Epoch 00050: val_loss improved from 0.24245 to 0.24004, saving model to ./model\50-0.2400.hdf5
#
# Epoch 00051: val_loss improved from 0.24004 to 0.23786, saving model to ./model\51-0.2379.hdf5
#
# Epoch 00052: val_loss improved from 0.23786 to 0.23591, saving model to ./model\52-0.2359.hdf5
#
# Epoch 00053: val_loss improved from 0.23591 to 0.23440, saving model to ./model\53-0.2344.hdf5
#
# Epoch 00054: val_loss improved from 0.23440 to 0.23352, saving model to ./model\54-0.2335.hdf5
#
# Epoch 00055: val_loss improved from 0.23352 to 0.23290, saving model to ./model\55-0.2329.hdf5
#
# Epoch 00056: val_loss improved from 0.23290 to 0.23245, saving model to ./model\56-0.2325.hdf5
#
# Epoch 00057: val_loss improved from 0.23245 to 0.23176, saving model to ./model\57-0.2318.hdf5
#
# Epoch 00058: val_loss improved from 0.23176 to 0.23101, saving model to ./model\58-0.2310.hdf5
#
# Epoch 00059: val_loss improved from 0.23101 to 0.22992, saving model to ./model\59-0.2299.hdf5
#
# Epoch 00060: val_loss improved from 0.22992 to 0.22861, saving model to ./model\60-0.2286.hdf5
#
# Epoch 00061: val_loss improved from 0.22861 to 0.22728, saving model to ./model\61-0.2273.hdf5
#
# Epoch 00062: val_loss improved from 0.22728 to 0.22596, saving model to ./model\62-0.2260.hdf5
#
# Epoch 00063: val_loss improved from 0.22596 to 0.22469, saving model to ./model\63-0.2247.hdf5
#
# Epoch 00064: val_loss improved from 0.22469 to 0.22409, saving model to ./model\64-0.2241.hdf5
#
# Epoch 00065: val_loss improved from 0.22409 to 0.22360, saving model to ./model\65-0.2236.hdf5
#
# Epoch 00066: val_loss improved from 0.22360 to 0.22305, saving model to ./model\66-0.2230.hdf5
#
# Epoch 00067: val_loss improved from 0.22305 to 0.22206, saving model to ./model\67-0.2221.hdf5
#
# Epoch 00068: val_loss improved from 0.22206 to 0.22130, saving model to ./model\68-0.2213.hdf5
#
# Epoch 00069: val_loss improved from 0.22130 to 0.22052, saving model to ./model\69-0.2205.hdf5
#
# Epoch 00070: val_loss improved from 0.22052 to 0.22027, saving model to ./model\70-0.2203.hdf5
#
# Epoch 00071: val_loss improved from 0.22027 to 0.22008, saving model to ./model\71-0.2201.hdf5
#
# Epoch 00072: val_loss improved from 0.22008 to 0.21987, saving model to ./model\72-0.2199.hdf5
#
# Epoch 00073: val_loss improved from 0.21987 to 0.21979, saving model to ./model\73-0.2198.hdf5
#
# Epoch 00074: val_loss did not improve from 0.21979
#
# Epoch 00075: val_loss did not improve from 0.21979
#
# Epoch 00076: val_loss improved from 0.21979 to 0.21973, saving model to ./model\76-0.2197.hdf5
#
# Epoch 00077: val_loss improved from 0.21973 to 0.21939, saving model to ./model\77-0.2194.hdf5
#
# Epoch 00078: val_loss improved from 0.21939 to 0.21876, saving model to ./model\78-0.2188.hdf5
#
# Epoch 00079: val_loss improved from 0.21876 to 0.21791, saving model to ./model\79-0.2179.hdf5
#
# Epoch 00080: val_loss improved from 0.21791 to 0.21697, saving model to ./model\80-0.2170.hdf5
#
# Epoch 00081: val_loss improved from 0.21697 to 0.21609, saving model to ./model\81-0.2161.hdf5
#
# Epoch 00082: val_loss improved from 0.21609 to 0.21557, saving model to ./model\82-0.2156.hdf5
#
# Epoch 00083: val_loss did not improve from 0.21557
#
# Epoch 00084: val_loss did not improve from 0.21557
#
# Epoch 00085: val_loss did not improve from 0.21557
#
# Epoch 00086: val_loss did not improve from 0.21557
#
# Epoch 00087: val_loss improved from 0.21557 to 0.21485, saving model to ./model\87-0.2149.hdf5
#
# Epoch 00088: val_loss improved from 0.21485 to 0.21353, saving model to ./model\88-0.2135.hdf5
#
# Epoch 00089: val_loss improved from 0.21353 to 0.21296, saving model to ./model\89-0.2130.hdf5
#
# Epoch 00090: val_loss improved from 0.21296 to 0.21285, saving model to ./model\90-0.2129.hdf5
#
# Epoch 00091: val_loss did not improve from 0.21285
#
# Epoch 00092: val_loss did not improve from 0.21285
#
# Epoch 00093: val_loss did not improve from 0.21285
#
# Epoch 00094: val_loss did not improve from 0.21285
#
# Epoch 00095: val_loss improved from 0.21285 to 0.21194, saving model to ./model\95-0.2119.hdf5
#
# Epoch 00096: val_loss improved from 0.21194 to 0.21123, saving model to ./model\96-0.2112.hdf5
# Epoch 00097: val_loss improved from 0.21123 to 0.21065, saving model to ./model\97-0.2107.hdf5
#
# Epoch 00098: val_loss improved from 0.21065 to 0.21029, saving model to ./model\98-0.2103.hdf5
#
# Epoch 00099: val_loss improved from 0.21029 to 0.20989, saving model to ./model\99-0.2099.hdf5
#
# Epoch 00100: val_loss improved from 0.20989 to 0.20958, saving model to ./model\100-0.2096.hdf5
